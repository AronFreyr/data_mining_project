# %%
from generate_data import *
from robust_gmm import RobustGMM
from sklearn.datasets import make_moons, make_circles, make_blobs
from sklearn.decomposition import PCA
import time

# %%
X = data_example_1()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_2()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_3()
rgmm = RobustGMM()
start = time.time()
rgmm.fit(X)
end  = time.time()
print(end - start)
rgmm.make_clusters()
rgmm.plot_predictions()
# Out:
# 5.5493505001068115

# %%
X = data_example_5()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_6()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()
len(np.unique(rgmm.clusters))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 16

# %%
moons = make_moons(n_samples=1000)
plt.scatter(moons[0][:, 0], moons[0][:, 1], c=moons[1], edgecolor="k")
plt.show()
rgmm = RobustGMM()
rgmm.fit(moons[0])
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
circles = make_circles(n_samples=1000, factor=0.5, noise=0.05)
plt.scatter(circles[0][:, 0], circles[0][:, 1], c=circles[1], edgecolor="k")
plt.show()
rgmm = RobustGMM()
rgmm.fit(circles[0])
rgmm.make_clusters()
rgmm.plot_predictions()
len(np.unique(rgmm.clusters))
# Out:
# 19

# %%
X = data_example_1_3D()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_7()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_2_2()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_5_2()
rgmm = RobustGMM()
rgmm.fit(X)
rgmm.make_clusters()
rgmm.plot_predictions()

# %%
X = data_example_3_2()
rgmm = RobustGMM()
start = time.time()
rgmm.fit(X)
end  = time.time()
print(end - start)
rgmm.make_clusters()
rgmm.plot_predictions()
# Out:
# 2434.8490624427795
